# %%
import pandas as pd

# %%
# Reading phenotype data
pheno = pd.read_csv("phenotype.csv")
pheno.head()
# Out:
# /var/folders/lt/nn7tpp3967v9_lrhrs65k5j80000gn/T/ipykernel_9507/1864351737.py:2: DtypeWarning: Columns (37,40,41,42,44,50,66,81,82,104,112,120,128,137,147,156,165,174,183,184,186,193,194,196,201,202,204,209,210,212,217,218,220,226,227,229,236,237,239,244,245,247,252,253,255,260,261,263,269,270,272,279,280,282,287,288,290,295,296,298,303,304,306,312,313,315,322,323,325,330,331,333,338,339,341,346,347,349,355,356,358,365,366,368,373,374,376,381,382,384,389,390,392,398,399,401,403,404,406,411,412,414,419,420,422,428,429,431,437,455,456,459,460,461,463,465,471,473,492) have mixed types. Specify dtype option on import or set low_memory=False.
#   pheno = pd.read_csv("phenotype.csv")
#     Unnamed: 0       pid    bid        labelid    viallabel key.protocol  \
# 0  90217013001  10023259  90217  4.457313e-313  90217013001     phase 1b
# 1  90217013104  10023259  90217  4.457313e-313  90217013104     phase 1b
# 2  90217013105  10023259  90217  4.457313e-313  90217013105     phase 1b
# 3  90217013106  10023259  90217  4.457313e-313  90217013106     phase 1b
# 4  90217013107  10023259  90217  4.457313e-313  90217013107     phase 1b
#
#   key.agegroup key.d_arrive key.d_sacrifice key.intervention  ...  \
# 0     6 months    05JUN2018       03SEP2018          control  ...
# 1     6 months    05JUN2018       03SEP2018          control  ...
# 2     6 months    05JUN2018       03SEP2018          control  ...
# 3     6 months    05JUN2018       03SEP2018          control  ...
# 4     6 months    05JUN2018       03SEP2018          control  ...
#
#   biclabeldata.protocol          study_group_timepoint sacrificetime  \
# 0              phase 1b  8 week control group (pass1b)            8w
# 1              phase 1b  8 week control group (pass1b)            8w
# 2              phase 1b  8 week control group (pass1b)            8w
# 3              phase 1b  8 week control group (pass1b)            8w
# 4              phase 1b  8 week control group (pass1b)            8w
#
#   intervention    group   sex time_to_freeze tissue_code_no  \
# 0      control  control  male           6821            T30
# 1      control  control  male           2174            T31
# 2      control  control  male           2174            T31
# 3      control  control  male           2174            T31
# 4      control  control  male           2174            T31
#
#    tissue_description  tissue
# 0         PaxGene RNA   BLOOD
# 1         EDTA Plasma  PLASMA
# 2         EDTA Plasma  PLASMA
# 3         EDTA Plasma  PLASMA
# 4         EDTA Plasma  PLASMA
#
# [5 rows x 510 columns]

# %%
pheno.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'pid',
#  'bid',
#  'labelid',
#  'viallabel',
#  'key.protocol',
#  'key.agegroup',
#  'key.d_arrive',
#  'key.d_sacrifice',
#  'key.intervention',
#  'key.sacrificetime',
#  'key.anirandgroup',
#  'key.siteid',
#  'familiarization.d_visit',
#  'familiarization.days_visit',
#  'familiarization.staffid',
#  'familiarization.siteid',
#  'familiarization.d_treadmillbegin',
#  'familiarization.days_treadmillbegin',
#  'familiarization.d_treadmillcomplete',
#  'familiarization.days_treadmillcomplete',
#  'familiarization.activity_score',
#  'familiarization.compliant',
#  'familiarization.weight',
#  'nmr.testing.d_visit_1',
#  'nmr.testing.days_visit_1',
#  'nmr.testing.staffid_1',
#  'nmr.testing.siteid_1',
#  'nmr.testing.visitcode_1',
#  'nmr.testing.formname_1',
#  'nmr.testing.versionnbr_1',
#  'nmr.testing.d_nmr_1',
#  'nmr.testing.days_nmr_1',
#  'nmr.testing.nmr_weight_1',
#  'nmr.testing.nmr_fat_1',
#  'nmr.testing.nmr_lean_1',
#  'nmr.testing.nmr_fluid_1',
#  'nmr.testing.d_visit_2',
#  'nmr.testing.days_visit_2',
#  'nmr.testing.staffid_2',
#  'nmr.testing.siteid_2',
#  'nmr.testing.visitcode_2',
#  'nmr.testing.formname_2',
#  'nmr.testing.versionnbr_2',
#  'nmr.testing.d_nmr_2',
#  'nmr.testing.days_nmr_2',
#  'nmr.testing.nmr_weight_2',
#  'nmr.testing.nmr_fat_2',
#  'nmr.testing.nmr_lean_2',
#  'nmr.testing.nmr_fluid_2',
#  'nmr.testing.nmr_comments_2',
#  'registration.d_visit',
#  'registration.days_visit',
#  'registration.staffid',
#  'registration.siteid',
#  'registration.ratid',
#  'registration.d_arrive',
#  'registration.days_arrive',
#  'registration.batchnumber',
#  'registration.d_reverselight',
#  'registration.days_reverselight',
#  'registration.d_birth',
#  'registration.days_birth',
#  'registration.sex',
#  'registration.weight',
#  'registration.cagenumber',
#  'registration.comments',
#  'specimen.collection.d_visit',
#  'specimen.collection.days_visit',
#  'specimen.collection.staffid',
#  'specimen.collection.siteid',
#  'specimen.collection.visitcode',
#  'specimen.collection.anesthesiaid',
#  'specimen.collection.t_anesthesia',
#  'specimen.collection.bloodtype',
#  'specimen.collection.bloodtube',
#  'specimen.collection.bloodcomplete',
#  'specimen.collection.bloodtechid',
#  'specimen.collection.t_bloodstart',
#  'specimen.collection.t_bloodstop',
#  'specimen.collection.t_edtafill',
#  'specimen.collection.bloodcomments',
#  'specimen.collection.uterustype',
#  'specimen.collection.uteruscomplete',
#  'specimen.collection.t_death',
#  'specimen.collection.deathtype',
#  'terminal.weight.bw',
#  'terminal.weight.lg',
#  'terminal.weight.mg',
#  'terminal.weight.pl',
#  'terminal.weight.sol',
#  'training.d_visit',
#  'training.days_visit',
#  'training.staffid',
#  'training.siteid',
#  'training.day1date',
#  'training.day1_days',
#  'training.day1time',
#  'training.day1_treadmillspeed',
#  'training.day1_treadmillincline',
#  'training.day1_timeontreadmill',
#  'training.day1_weight',
#  'training.day1_posttrainlact',
#  'training.day1_score',
#  'training.day1_comments',
#  'training.day2date',
#  'training.day2_days',
#  'training.day2time',
#  'training.day2_treadmillspeed',
#  'training.day2_treadmillincline',
#  'training.day2_timeontreadmill',
#  'training.day2_score',
#  'training.day2_comments',
#  'training.day3date',
#  'training.day3_days',
#  'training.day3time',
#  'training.day3_treadmillspeed',
#  'training.day3_treadmillincline',
#  'training.day3_timeontreadmill',
#  'training.day3_score',
#  'training.day3_comments',
#  'training.day4date',
#  'training.day4_days',
#  'training.day4time',
#  'training.day4_treadmillspeed',
#  'training.day4_treadmillincline',
#  'training.day4_timeontreadmill',
#  'training.day4_score',
#  'training.day4_comments',
#  'training.day5date',
#  'training.day5_days',
#  'training.day5time',
#  'training.day5_treadmillspeed',
#  'training.day5_treadmillincline',
#  'training.day5_timeontreadmill',
#  'training.day5_posttrainlact',
#  'training.day5_score',
#  'training.day5_comments',
#  'training.day6date',
#  'training.day6_days',
#  'training.day6time',
#  'training.day6_treadmillspeed',
#  'training.day6_treadmillincline',
#  'training.day6_timeontreadmill',
#  'training.day6_weight',
#  'training.day6_posttrainlact',
#  'training.day6_score',
#  'training.day6_comments',
#  'training.day7date',
#  'training.day7_days',
#  'training.day7time',
#  'training.day7_treadmillspeed',
#  'training.day7_treadmillincline',
#  'training.day7_timeontreadmill',
#  'training.day7_posttrainlact',
#  'training.day7_score',
#  'training.day7_comments',
#  'training.day8date',
#  'training.day8_days',
#  'training.day8time',
#  'training.day8_treadmillspeed',
#  'training.day8_treadmillincline',
#  'training.day8_timeontreadmill',
#  'training.day8_posttrainlact',
#  'training.day8_score',
#  'training.day8_comments',
#  'training.day9date',
#  'training.day9_days',
#  'training.day9time',
#  'training.day9_treadmillspeed',
#  'training.day9_treadmillincline',
#  'training.day9_timeontreadmill',
#  'training.day9_posttrainlact',
#  'training.day9_score',
#  'training.day9_comments',
#  'training.day10date',
#  'training.day10_days',
#  'training.day10time',
#  'training.day10_treadmillspeed',
#  'training.day10_treadmillincline',
#  'training.day10_timeontreadmill',
#  'training.day10_posttrainlact',
#  'training.day10_score',
#  'training.day10_comments',
#  'training.day11date',
#  'training.day11_days',
#  'training.day11time',
#  'training.day11_treadmillspeed',
#  'training.day11_treadmillincline',
#  'training.day11_timeontreadmill',
#  'training.day11_weight',
#  'training.day11_posttrainlact',
#  'training.day11_score',
#  'training.day11_comments',
#  'training.day12date',
#  'training.day12_days',
#  'training.day12time',
#  'training.day12_treadmillspeed',
#  'training.day12_treadmillincline',
#  'training.day12_timeontreadmill',
#  'training.day12_score',
#  'training.day12_comments',
#  'training.day13date',
#  'training.day13_days',
#  'training.day13time',
#  'training.day13_treadmillspeed',
#  'training.day13_treadmillincline',
#  'training.day13_timeontreadmill',
#  'training.day13_score',
#  'training.day13_comments',
#  'training.day14date',
#  'training.day14_days',
#  'training.day14time',
#  'training.day14_treadmillspeed',
#  'training.day14_treadmillincline',
#  'training.day14_timeontreadmill',
#  'training.day14_score',
#  'training.day14_comments',
#  'training.day15date',
#  'training.day15_days',
#  'training.day15time',
#  'training.day15_treadmillspeed',
#  'training.day15_treadmillincline',
#  'training.day15_timeontreadmill',
#  'training.day15_posttrainlact',
#  'training.day15_score',
#  'training.day15_comments',
#  'training.day16date',
#  'training.day16_days',
#  'training.day16time',
#  'training.day16_treadmillspeed',
#  'training.day16_treadmillincline',
#  'training.day16_timeontreadmill',
#  'training.day16_weight',
#  'training.day16_posttrainlact',
#  'training.day16_score',
#  'training.day16_comments',
#  'training.day17date',
#  'training.day17_days',
#  'training.day17time',
#  'training.day17_treadmillspeed',
#  'training.day17_treadmillincline',
#  'training.day17_timeontreadmill',
#  'training.day17_score',
#  'training.day17_comments',
#  'training.day18date',
#  'training.day18_days',
#  'training.day18time',
#  'training.day18_treadmillspeed',
#  'training.day18_treadmillincline',
#  'training.day18_timeontreadmill',
#  'training.day18_score',
#  'training.day18_comments',
#  'training.day19date',
#  'training.day19_days',
#  'training.day19time',
#  'training.day19_treadmillspeed',
#  'training.day19_treadmillincline',
#  'training.day19_timeontreadmill',
#  'training.day19_score',
#  'training.day19_comments',
#  'training.day20date',
#  'training.day20_days',
#  'training.day20time',
#  'training.day20_treadmillspeed',
#  'training.day20_treadmillincline',
#  'training.day20_timeontreadmill',
#  'training.day20_posttrainlact',
#  'training.day20_score',
#  'training.day20_comments',
#  'training.day21date',
#  'training.day21_days',
#  'training.day21time',
#  'training.day21_treadmillspeed',
#  'training.day21_treadmillincline',
#  'training.day21_timeontreadmill',
#  'training.day21_weight',
#  'training.day21_posttrainlact',
#  'training.day21_score',
#  'training.day21_comments',
#  'training.day22date',
#  'training.day22_days',
#  'training.day22time',
#  'training.day22_treadmillspeed',
#  'training.day22_treadmillincline',
#  'training.day22_timeontreadmill',
#  'training.day22_score',
#  'training.day22_comments',
#  'training.day23date',
#  'training.day23_days',
#  'training.day23time',
#  'training.day23_treadmillspeed',
#  'training.day23_treadmillincline',
#  'training.day23_timeontreadmill',
#  'training.day23_score',
#  'training.day23_comments',
#  'training.day24date',
#  'training.day24_days',
#  'training.day24time',
#  'training.day24_treadmillspeed',
#  'training.day24_treadmillincline',
#  'training.day24_timeontreadmill',
#  'training.day24_score',
#  'training.day24_comments',
#  'training.day25date',
#  'training.day25_days',
#  'training.day25time',
#  'training.day25_treadmillspeed',
#  'training.day25_treadmillincline',
#  'training.day25_timeontreadmill',
#  'training.day25_posttrainlact',
#  'training.day25_score',
#  'training.day25_comments',
#  'training.day26date',
#  'training.day26_days',
#  'training.day26time',
#  'training.day26_treadmillspeed',
#  'training.day26_treadmillincline',
#  'training.day26_timeontreadmill',
#  'training.day26_weight',
#  'training.day26_posttrainlact',
#  'training.day26_score',
#  'training.day26_comments',
#  'training.day27date',
#  'training.day27_days',
#  'training.day27time',
#  'training.day27_treadmillspeed',
#  'training.day27_treadmillincline',
#  'training.day27_timeontreadmill',
#  'training.day27_score',
#  'training.day27_comments',
#  'training.day28date',
#  'training.day28_days',
#  'training.day28time',
#  'training.day28_treadmillspeed',
#  'training.day28_treadmillincline',
#  'training.day28_timeontreadmill',
#  'training.day28_score',
#  'training.day28_comments',
#  'training.day29date',
#  'training.day29_days',
#  'training.day29time',
#  'training.day29_treadmillspeed',
#  'training.day29_treadmillincline',
#  'training.day29_timeontreadmill',
#  'training.day29_score',
#  'training.day29_comments',
#  'training.day30date',
#  'training.day30_days',
#  'training.day30time',
#  'training.day30_treadmillspeed',
#  'training.day30_treadmillincline',
#  'training.day30_timeontreadmill',
#  'training.day30_posttrainlact',
#  'training.day30_score',
#  'training.day30_comments',
#  'training.day31date',
#  'training.day31_days',
#  'training.day31time',
#  'training.day31_treadmillspeed',
#  'training.day31_treadmillincline',
#  'training.day31_timeontreadmill',
#  'training.day31_weight',
#  'training.day31_posttrainlact',
#  'training.day31_score',
#  'training.day31_comments',
#  'training.day32date',
#  'training.day32_days',
#  'training.day32time',
#  'training.day32_treadmillspeed',
#  'training.day32_treadmillincline',
#  'training.day32_timeontreadmill',
#  'training.day32_score',
#  'training.day32_comments',
#  'training.day33date',
#  'training.day33_days',
#  'training.day33time',
#  'training.day33_treadmillspeed',
#  'training.day33_treadmillincline',
#  'training.day33_timeontreadmill',
#  'training.day33_score',
#  'training.day33_comments',
#  'training.day34date',
#  'training.day34_days',
#  'training.day34time',
#  'training.day34_treadmillspeed',
#  'training.day34_treadmillincline',
#  'training.day34_timeontreadmill',
#  'training.day34_score',
#  'training.day34_comments',
#  'training.day35date',
#  'training.day35_days',
#  'training.day35time',
#  'training.day35_treadmillspeed',
#  'training.day35_treadmillincline',
#  'training.day35_timeontreadmill',
#  'training.day35_posttrainlact',
#  'training.day35_score',
#  'training.day35_comments',
#  'training.day36date',
#  'training.day36_days',
#  'training.day36time',
#  'training.day36_weight',
#  'training.day36_comments',
#  'training.day37date',
#  'training.day37_days',
#  'training.day37time',
#  'training.day37_treadmillspeed',
#  'training.day37_treadmillincline',
#  'training.day37_timeontreadmill',
#  'training.day37_score',
#  'training.day37_comments',
#  'training.day38date',
#  'training.day38_days',
#  'training.day38time',
#  'training.day38_treadmillspeed',
#  'training.day38_treadmillincline',
#  'training.day38_timeontreadmill',
#  'training.day38_score',
#  'training.day38_comments',
#  'training.day39date',
#  'training.day39_days',
#  'training.day39time',
#  'training.day39_treadmillspeed',
#  'training.day39_treadmillincline',
#  'training.day39_timeontreadmill',
#  'training.day39_posttrainlact',
#  'training.day39_score',
#  'training.day39_comments',
#  'training.day40date',
#  'training.day40_days',
#  'training.day40time',
#  'training.day40_treadmillspeed',
#  'training.day40_treadmillincline',
#  'training.day40_timeontreadmill',
#  'training.day40_posttrainlact',
#  'training.day40_score',
#  'training.day40_comments',
#  'vo2.max.test.d_visit_1',
#  'vo2.max.test.days_visit_1',
#  'vo2.max.test.staffid_1',
#  'vo2.max.test.siteid_1',
#  'vo2.max.test.visitcode_1',
#  'vo2.max.test.formname_1',
#  'vo2.max.test.versionnbr_1',
#  'vo2.max.test.d_vo2_1',
#  'vo2.max.test.days_vo2_1',
#  'vo2.max.test.t_vo2_1',
#  'vo2.max.test.blactate_begin_1',
#  'vo2.max.test.vo2_max_1',
#  'vo2.max.test.vco2_max_1',
#  'vo2.max.test.rer_max_1',
#  'vo2.max.test.speed_max_1',
#  'vo2.max.test.t_complete_1',
#  'vo2.max.test.blactate_end_1',
#  'vo2.max.test.vo2_comments_1',
#  'vo2.max.test.d_visit_2',
#  'vo2.max.test.days_visit_2',
#  'vo2.max.test.staffid_2',
#  'vo2.max.test.siteid_2',
#  'vo2.max.test.visitcode_2',
#  'vo2.max.test.formname_2',
#  'vo2.max.test.versionnbr_2',
#  'vo2.max.test.d_vo2_2',
#  'vo2.max.test.days_vo2_2',
#  'vo2.max.test.t_vo2_2',
#  'vo2.max.test.blactate_begin_2',
#  'vo2.max.test.vo2_max_2',
#  'vo2.max.test.vco2_max_2',
#  'vo2.max.test.rer_max_2',
#  'vo2.max.test.speed_max_2',
#  'vo2.max.test.t_complete_2',
#  'vo2.max.test.blactate_end_2',
#  'vo2.max.test.vo2_comments_2',
#  'calculated.variables.pct_body_fat_change',
#  'calculated.variables.pct_body_lean_change',
#  'calculated.variables.pct_body_fluid_change',
#  'calculated.variables.lactate_change_dueto_train',
#  'calculated.variables.vo2_max_change',
#  'calculated.variables.coll_time_train',
#  'calculated.variables.deathtime_after_train',
#  'calculated.variables.frozetime_after_train',
#  'specimen.processing.versionnbr',
#  'specimen.processing.formname',
#  'specimen.processing.visitcode',
#  'specimen.processing.siteid',
#  'specimen.processing.sampletypedescription',
#  'specimen.processing.samplenumber',
#  'specimen.processing.timepoint',
#  'specimen.processing.aliquotdescription',
#  'specimen.processing.volume',
#  'specimen.processing.hemolyzed',
#  'specimen.processing.comments',
#  'specimen.processing.t_collection',
#  'specimen.processing.t_edtaspin',
#  'specimen.processing.t_freeze',
#  'specimen.processing.techid',
#  'biclabeldata.barcode',
#  'biclabeldata.shiptositeid',
#  'biclabeldata.received_cas',
#  'biclabeldata.protocol',
#  'study_group_timepoint',
#  'sacrificetime',
#  'intervention',
#  'group',
#  'sex',
#  'time_to_freeze',
#  'tissue_code_no',
#  'tissue_description',
#  'tissue']

# %%
pheno["vo2.max.test.vo2_max_2"]
# Out:
# 0       63.47
# 1       63.47
# 2       63.47
# 3       63.47
# 4       63.47
#         ...
# 6151      NaN
# 6152      NaN
# 6153      NaN
# 6154      NaN
# 6155      NaN
# Name: vo2.max.test.vo2_max_2, Length: 6156, dtype: float64

# %%
pheno["sex"]
# Out:
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 6151    female
# 6152    female
# 6153    female
# 6154    female
# 6155    female
# Name: sex, Length: 6156, dtype: object

# %%
pheno["group"].to_list()
# Out:
# ['control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  'control',
#  'control',
#  'control',
#  'control',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  'control',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  '8w',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  ...]

# %%
pheno["sacrificetime"].to_list()
# Out:
# ['8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  '8w',
#  ...]

# %%
import seaborn as sns

# %%
sns.histplot(pheno["vo2.max.test.vo2_max_2"])
# Out:
# <Axes: xlabel='vo2.max.test.vo2_max_2', ylabel='Count'>

# %%
phenoSubset = pheno[["pid", 
                     "viallabel", 
                     "sex", 
                     "vo2.max.test.vo2_max_2", 
                     "registration.weight", 
                     "terminal.weight.bw", 
                     "group"]]
phenoSubset.head()
# Out:
#         pid    viallabel   sex  vo2.max.test.vo2_max_2  registration.weight  \
# 0  10023259  90217013001  male                   63.47                335.0
# 1  10023259  90217013104  male                   63.47                335.0
# 2  10023259  90217013105  male                   63.47                335.0
# 3  10023259  90217013106  male                   63.47                335.0
# 4  10023259  90217013107  male                   63.47                335.0
#
#    terminal.weight.bw    group
# 0               346.2  control
# 1               346.2  control
# 2               346.2  control
# 3               346.2  control
# 4               346.2  control

# %%
phenoSubset["mass_lost"] = phenoSubset["registration.weight"] - phenoSubset["terminal.weight.bw"]

phenoSubset["norm_mass_lost"] = phenoSubset["mass_lost"] / phenoSubset["registration.weight"]
# Out:
# /var/folders/lt/nn7tpp3967v9_lrhrs65k5j80000gn/T/ipykernel_9507/1623163397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phenoSubset["mass_lost"] = phenoSubset["registration.weight"] - phenoSubset["terminal.weight.bw"]
# /var/folders/lt/nn7tpp3967v9_lrhrs65k5j80000gn/T/ipykernel_9507/1623163397.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phenoSubset["norm_mass_lost"] = phenoSubset["mass_lost"] / phenoSubset["registration.weight"]

# %%
phenoSubset.head()
# Out:
#         pid    viallabel   sex  vo2.max.test.vo2_max_2  registration.weight  \
# 0  10023259  90217013001  male                   63.47                335.0
# 1  10023259  90217013104  male                   63.47                335.0
# 2  10023259  90217013105  male                   63.47                335.0
# 3  10023259  90217013106  male                   63.47                335.0
# 4  10023259  90217013107  male                   63.47                335.0
#
#    terminal.weight.bw    group  mass_lost  norm_mass_lost
# 0               346.2  control      -11.2       -0.033433
# 1               346.2  control      -11.2       -0.033433
# 2               346.2  control      -11.2       -0.033433
# 3               346.2  control      -11.2       -0.033433
# 4               346.2  control      -11.2       -0.033433

# %%
phenoSubset.to_csv("phenoSubset.csv")
